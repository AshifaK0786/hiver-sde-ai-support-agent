# %% [markdown]
# # Hiver — Data Exploration\nRun the exploration only after placing the real dataset in `data/raw/`.

# %%
from pathlib import Path\nimport pandas as pd\n\nfiles = list(Path('../data/raw').glob('*.csv'))\nfiles
